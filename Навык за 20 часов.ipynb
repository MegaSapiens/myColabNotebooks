# %% [markdown]
# #сформировать любой навык за 20 часов

# %% [markdown]
# ##1 час.
# (Зафиксируй свои результаты тут)

# %%
while 1:
  otvet = input('Что требуется делать используя навык? ')
  break
otvet

# %% [markdown]
# ##2 час.
# (Зафиксируй свои результаты тут)

# %%
while 1:
  otvet2 = input(f'Почему и зачем нужно будет это({otvet}) делать используя навык?')
  break
otvet2

# %% [markdown]
# ##3 час.
# (Зафиксируй свои результаты тут)

# %%
while 1:
  otvet3 = input('Кому нужно сформировать навык?')
  break
otvet3

# %% [markdown]
# ##4 час.
# (Зафиксируй свои результаты тут)

# %%
while 1:
  otvet4 = input('Где нужно формировать навык, а где не желательно? ')
  break
otvet4

# %% [markdown]
# ##5 час.
# (Зафиксируй свои результаты тут)

# %%
while 1:
  otvet5 = input('С какого момента нужно начать формирование навыка?')
  break
otvet5

# %% [markdown]
# ##6 час.
# (Зафиксируй свои результаты тут)

# %%
while 1:
  otvet6 = input('Какой способ выбран для формирования навыка?')
  break
otvet6

# %% [markdown]
# ##7 час.
# (Зафиксируй свои результаты тут)

# %%
while 1:
  otvet7 = input('#Изучить навык')
  break
otvet7

# %% [markdown]
# ##8 час.
# (Зафиксируй свои результаты тут)

# %%
while 1:
  otvet8 = input('#Сформитровать навык ')
  break
otvet8

# %% [markdown]
# ##9 час.
# (Зафиксируй свои результаты тут)

# %%
while 1:
  otvet9 = input('#Протестировать навык ')
  break
otvet9

# %% [markdown]
# ##10 час.
# (Зафиксируй свои результаты тут)

# %%
while 1:
  otvet10 = input('#Организовать наблюдение за формированием навыка ')
  break
otvet10

# %% [markdown]
# ##11 час.
# (Зафиксируй свои результаты тут)

# %%
while 1:
  otvet11 = input('#Лишить недостатков в навыке')
  break
otvet11

# %% [markdown]
# ##12 час.
# (Зафиксируй свои результаты тут)

# %%
while 1:
  otvet12 = input('#напиши о приобретённом навыке')
  break
otvet12

# %% [markdown]
# ##13 час.
# (Зафиксируй свои результаты тут)

# %%
while 1:
  otvet13 = input('#информируй о приобретённом навыке ')
  break
otvet13

# %% [markdown]
# ##14 час.
# (Зафиксируй свои результаты тут)

# %%
while 1:
  otvet14 = input('#Какой статус у процесса получения навыка?')
  break
otvet14

# %% [markdown]
# ##15 час.
# (Зафиксируй свои результаты тут)

# %%
while 1:
  otvet15 = input('ИСПОЛНИ ещё раз ')
  break
otvet15

# %% [markdown]
# ##16 час.
# (Зафиксируй свои результаты тут)

# %%
while 1:
  otvet16 = input('ИСПОЛНИ 2-й раз')
  break
otvet16

# %% [markdown]
# ##17  час.
# (Зафиксируй свои результаты тут)

# %%
while 1:
  otvet17 = input('ИСПОЛНИ 3-й раз')
  break
otvet17

# %% [markdown]
# ##18  час.
# (Зафиксируй свои результаты тут)

# %%
while 1:
  otvet18 = input('ИСПОЛНИ 4-й раз')
  break
otvet18

# %% [markdown]
# ##19  час.
# (Зафиксируй свои результаты тут)

# %%
while 1:
  otvet19 = input('ИСПОЛНИ 5-й раз')
  break
otvet19

# %% [markdown]
# ##20 последний  час.
# (Зафиксируй свои результаты тут)
# Первый блин был такой
# ```Зафиксируй результат формирования навыка выполняя часами алгоритм ИСПОЛНИ ок
# ('готово 2.12.23 16:57',
#  'чтобы уложиться за 20 часов и стать специалистом начального уровня',
#  'мне или тебе или кому-то нельзя',
#  'Смотря кому',
#  'Начали уже 5 часов назад.',
#  'ИСПОЛНИ',
#  '7 часов как',
#  'готово 2.12.23 16:57',
#  'запустил на выполнение с 10 по 20 час',
#  'организовано в рамках данного блокнота',
#  '20 час уже скоро',
#  '21 минуту сегодня если что',
#  'напишу Свете письмо',
#  'исполняется',
#  '2 раз',
#  '2 раз',
#  '3 раз',
#  '4 раз',
#  '5 раз ИСПОЛНИ',
#  'ок')
# ```
# ### Выбран кодовый формат

# %%
while 1:
  otvet20 = input('Зафиксируй результат формирования навыка выполняя часами алгоритм ИСПОЛНИ ')
  break
(otvet, otvet2, otvet3, otvet4, otvet5, otvet6, otvet7, otvet8, otvet9, otvet10, otvet11, otvet12, otvet13, otvet14, otvet15, otvet16, otvet17, otvet18, otvet19, otvet20)
